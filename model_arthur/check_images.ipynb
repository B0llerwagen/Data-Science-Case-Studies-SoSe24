# %%
import pickle
#import numpy as np

with open("../model_arthur/data/data_useable.pickle", "rb") as f:
    train_images, train_labels = pickle.load(f)

# %%
# Displaying the first picture
first_picture = train_images[0]

# Ensure the data is clipped within the valid range for imshow
first_picture = np.clip(first_picture, 0, 255)
plt.imshow(first_picture.astype(np.uint8))
#plt.tight_layout()
plt.show()

# %%
import numpy as np
train_images = np.array(train_images.astype(np.float32))

# %%
import matplotlib.pyplot as plt
import numpy as np


X_train_image = train_images.astype(np.uint8)
fig, axes = plt.subplots(3, 3, figsize=(10, 10))

fig, axes = plt.subplots(3, 3, figsize=(10, 10))
for i, ax in enumerate(axes.flat):
  idx = np.random.randint(X_train_image.shape[0])
  ax.imshow(X_train_image[idx])
  ax.set_title(str(train_labels[idx]))
  ax.axis('off')
plt.tight_layout()
plt.show()
