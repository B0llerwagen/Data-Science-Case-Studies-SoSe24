# %%
import pickle

# Load the augmented images and labels from the file
with open('../../local_data/data_useable_6.pickle', 'rb') as f:
    augmented_images, augmented_labels = pickle.load(f)

# %%
augmented_images.shape, augmented_labels.shape
# Out:
# ((2200, 512, 512, 3), (2200, 2))

# %%
import tensorflow as tf
import numpy as np

augmented_images = np.array(augmented_images, dtype=np.float32)
augmented_labels = np.array(augmented_labels, dtype=np.int32)

from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(augmented_images, augmented_labels, test_size=0.2, random_state=42)

# %%
X_train.shape, y_train.shape, X_val.shape, y_val.shape
# Out:
# ((1760, 512, 512, 3), (1760, 2), (440, 512, 512, 3), (440, 2))

# %%
import tensorflow as tf
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Normalization, Flatten
from tensorflow.keras.models import Model

base_model = MobileNetV2(input_shape=(512, 512, 3), include_top=False, weights='imagenet')

base_model.trainable = False

x = base_model.output
x = Conv2D(512, (3, 3), activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
x = Normalization()(x)

x = Conv2D(512, (3, 3), activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
x = Normalization()(x)
x = Flatten()(x)

x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(2, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)
# Out:
# /var/folders/qx/nn7p1qjs7xg_z1q9j7km_bv80000gn/T/ipykernel_2082/1369170771.py:6: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(input_shape=(512, 512, 3), include_top=False, weights='imagenet')

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
callbacks = [ModelCheckpoint(filepath='../../models/pre_model_2_3.keras', monitor='val_loss', mode='min', save_best_only=True)]

history = model.fit(
  X_train,
  y_train, 
  epochs=20, 
  validation_data=(X_val, y_val),
  callbacks=callbacks
  )
# Out:
# Epoch 1/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.6666 - loss: 2.8043 - val_accuracy: 0.9182 - val_loss: 0.2283
# Epoch 2/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9387 - loss: 0.1651 - val_accuracy: 0.9682 - val_loss: 0.0807
# Epoch 3/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9874 - loss: 0.0403 - val_accuracy: 0.9727 - val_loss: 0.0816
# Epoch 4/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9975 - loss: 0.0123 - val_accuracy: 0.9773 - val_loss: 0.0456
# Epoch 5/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9903 - loss: 0.0273 - val_accuracy: 0.9591 - val_loss: 0.1546
# Epoch 6/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 74s 1s/step - accuracy: 0.9737 - loss: 0.1410 - val_accuracy: 0.9705 - val_loss: 0.1346
# Epoch 7/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9879 - loss: 0.0419 - val_accuracy: 0.9614 - val_loss: 0.1088
# Epoch 8/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 74s 1s/step - accuracy: 0.9875 - loss: 0.0376 - val_accuracy: 0.9841 - val_loss: 0.0320
# Epoch 9/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9976 - loss: 0.0042 - val_accuracy: 0.9955 - val_loss: 0.0236
# Epoch 10/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9948 - loss: 0.0068 - val_accuracy: 0.9773 - val_loss: 0.1439
# Epoch 11/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1026s 19s/step - accuracy: 0.9888 - loss: 0.0243 - val_accuracy: 0.9682 - val_loss: 0.0884
# Epoch 12/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 510s 9s/step - accuracy: 0.9898 - loss: 0.0500 - val_accuracy: 0.9205 - val_loss: 0.2314
# Epoch 13/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9869 - loss: 0.0644 - val_accuracy: 0.9750 - val_loss: 0.0424
# Epoch 14/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9981 - loss: 0.0081 - val_accuracy: 0.9795 - val_loss: 0.0545
# Epoch 15/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9954 - loss: 0.0110 - val_accuracy: 0.9773 - val_loss: 0.0762
# Epoch 16/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9969 - loss: 0.0060 - val_accuracy: 0.9841 - val_loss: 0.0402
# Epoch 17/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9980 - loss: 0.0034 - val_accuracy: 0.9864 - val_loss: 0.0292
# Epoch 18/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9970 - loss: 0.0042 - val_accuracy: 0.9864 - val_loss: 0.0327
# Epoch 19/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9964 - loss: 0.0040 - val_accuracy: 0.9864 - val_loss: 0.0323
# Epoch 20/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9975 - loss: 0.0060 - val_accuracy: 0.9864 - val_loss: 0.0316
# Epoch 21/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9977 - loss: 0.0029 - val_accuracy: 0.9864 - val_loss: 0.0312
# Epoch 22/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9975 - loss: 0.0027 - val_accuracy: 0.9864 - val_loss: 0.0314
# Epoch 23/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9959 - loss: 0.0035 - val_accuracy: 0.9864 - val_loss: 0.0306
# Epoch 24/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9985 - loss: 0.0020 - val_accuracy: 0.9864 - val_loss: 0.0303
# Epoch 25/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9952 - loss: 0.0049 - val_accuracy: 0.9864 - val_loss: 0.0300
# Epoch 26/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9956 - loss: 0.0042 - val_accuracy: 0.9864 - val_loss: 0.0301
# Epoch 27/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9970 - loss: 0.0037 - val_accuracy: 0.9864 - val_loss: 0.0300
# Epoch 28/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9983 - loss: 0.0024 - val_accuracy: 0.9864 - val_loss: 0.0314
# Epoch 29/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9976 - loss: 0.0031 - val_accuracy: 0.9864 - val_loss: 0.0307
# Epoch 30/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 73s 1s/step - accuracy: 0.9946 - loss: 0.0046 - val_accuracy: 0.9864 - val_loss: 0.0304
# Epoch 31/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9985 - loss: 0.0025 - val_accuracy: 0.9864 - val_loss: 0.0304
# Epoch 32/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 72s 1s/step - accuracy: 0.9976 - loss: 0.0030 - val_accuracy: 0.9864 - val_loss: 0.0307
# Epoch 33/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 72s 1s/step - accuracy: 0.9968 - loss: 0.0039 - val_accuracy: 0.9864 - val_loss: 0.0305
# Epoch 34/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 73s 1s/step - accuracy: 0.9986 - loss: 0.0022 - val_accuracy: 0.9864 - val_loss: 0.0304
# Epoch 35/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9987 - loss: 0.0034 - val_accuracy: 0.9864 - val_loss: 0.0307
# Epoch 36/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9980 - loss: 0.0025 - val_accuracy: 0.9864 - val_loss: 0.0308
# Epoch 37/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 73s 1s/step - accuracy: 0.9978 - loss: 0.0037 - val_accuracy: 0.9864 - val_loss: 0.0309
# Epoch 38/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 74s 1s/step - accuracy: 0.9991 - loss: 0.0022 - val_accuracy: 0.9864 - val_loss: 0.0311
# Epoch 39/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.9980 - loss: 0.0027 - val_accuracy: 0.9864 - val_loss: 0.0314
# Epoch 40/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9963 - loss: 0.0041 - val_accuracy: 0.9864 - val_loss: 0.0315

# %%
# Optionally, plot training history
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss over Epochs')

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy over Epochs')

plt.show()

# %%
model.save('../../models/pre_model_6_1_40_epochs.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
